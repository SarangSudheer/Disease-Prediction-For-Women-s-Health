# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,classification_report

# %%
raw_data=pd.read_csv("HeartAttack.csv")

# %%
raw_data
# Out:
#       Age  Gender  Heart rate  Systolic blood pressure  \
# 0      64       1          66                      160
# 1      21       1          94                       98
# 2      55       1          64                      160
# 3      64       1          70                      120
# 4      55       1          64                      112
# ...   ...     ...         ...                      ...
# 1314   44       1          94                      122
# 1315   66       1          84                      125
# 1316   45       1          85                      168
# 1317   54       1          58                      117
# 1318   51       1          94                      157
#
#       Diastolic blood pressure  Blood sugar  CK-MB  Troponin    Result
# 0                           83        160.0   1.80     0.012  negative
# 1                           46        296.0   6.75     1.060  positive
# 2                           77        270.0   1.99     0.003  negative
# 3                           55        270.0  13.87     0.122  positive
# 4                           65        300.0   1.08     0.003  negative
# ...                        ...          ...    ...       ...       ...
# 1314                        67        204.0   1.63     0.006  negative
# 1315                        55        149.0   1.33     0.172  positive
# 1316                       104         96.0   1.24     4.250  positive
# 1317                        68        443.0   5.80     0.359  positive
# 1318                        79        134.0  50.89     1.770  positive
#
# [1319 rows x 9 columns]

# %% [markdown]
# # Cleaning and pre-processing the dataset

# %%
raw_data.isnull().sum()
# Out:
# Age                         0
# Gender                      0
# Heart rate                  0
# Systolic blood pressure     0
# Diastolic blood pressure    0
# Blood sugar                 0
# CK-MB                       0
# Troponin                    0
# Result                      0
# dtype: int64

# %%
raw_data.duplicated().sum()
# Out:
# 0

# %%
raw_data.columns
# Out:
# Index(['Age', 'Gender', 'Heart rate', 'Systolic blood pressure',
#        'Diastolic blood pressure', 'Blood sugar', 'CK-MB', 'Troponin',
#        'Result'],
#       dtype='object')

# %%
raw_data.isna().sum()
# Out:
# Age                         0
# Gender                      0
# Heart rate                  0
# Systolic blood pressure     0
# Diastolic blood pressure    0
# Blood sugar                 0
# CK-MB                       0
# Troponin                    0
# Result                      0
# dtype: int64

# %%
raw_data["Result"]=raw_data["Result"].map({"negative":0,"positive":1}).copy()
raw_data
# Out:
#       Age  Gender  Heart rate  Systolic blood pressure  \
# 0      64       1          66                      160
# 1      21       1          94                       98
# 2      55       1          64                      160
# 3      64       1          70                      120
# 4      55       1          64                      112
# ...   ...     ...         ...                      ...
# 1314   44       1          94                      122
# 1315   66       1          84                      125
# 1316   45       1          85                      168
# 1317   54       1          58                      117
# 1318   51       1          94                      157
#
#       Diastolic blood pressure  Blood sugar  CK-MB  Troponin  Result
# 0                           83        160.0   1.80     0.012       0
# 1                           46        296.0   6.75     1.060       1
# 2                           77        270.0   1.99     0.003       0
# 3                           55        270.0  13.87     0.122       1
# 4                           65        300.0   1.08     0.003       0
# ...                        ...          ...    ...       ...     ...
# 1314                        67        204.0   1.63     0.006       0
# 1315                        55        149.0   1.33     0.172       1
# 1316                       104         96.0   1.24     4.250       1
# 1317                        68        443.0   5.80     0.359       1
# 1318                        79        134.0  50.89     1.770       1
#
# [1319 rows x 9 columns]

# %%
core_data=raw_data[(raw_data["Gender"]==0)].copy()
core_data=core_data[["Age","Heart rate","Systolic blood pressure","Diastolic blood pressure","Blood sugar","CK-MB","Troponin","Result"]].copy()
core_data=core_data.reset_index(drop=True).copy()

# %%
core_data[core_data["Result"]==1]
# Out:
#      Age  Heart rate  Systolic blood pressure  Diastolic blood pressure  \
# 6     86          73                      114                        68
# 10    47          66                      134                        57
# 13    58          96                      111                        74
# 16    63          81                      130                        65
# 18    28          78                      127                        61
# ..   ...         ...                      ...                       ...
# 443   47          58                       93                        78
# 444   55          80                      117                        83
# 445   56          68                      123                        70
# 446   60          78                      109                        69
# 447   70          80                      135                        75
#
#      Blood sugar   CK-MB  Troponin  Result
# 6           87.0    1.11     0.776       1
# 10         279.0  300.00     0.007       1
# 13          99.0    1.29     0.026       1
# 16          98.0    2.28     0.040       1
# 18         114.0   19.47     0.010       1
# ..           ...     ...       ...     ...
# 443        170.0    1.19     0.068       1
# 444        200.0    0.78     0.052       1
# 445        102.0    2.28     0.255       1
# 446        230.0   19.47     0.003       1
# 447        351.0    2.21    10.000       1
#
# [247 rows x 8 columns]

# %%
core_data[core_data["Result"]==0]
# Out:
#      Age  Heart rate  Systolic blood pressure  Diastolic blood pressure  \
# 0     58          61                      112                        58
# 1     32          40                      179                        68
# 2     44          60                      154                        81
# 3     44          60                      166                        90
# 4     63          60                      150                        83
# ..   ...         ...                      ...                       ...
# 434   55          73                      138                        79
# 438   42          70                      117                        76
# 441   62          60                      145                        67
# 442   67          81                      150                        75
# 448   86          40                      179                        68
#
#      Blood sugar  CK-MB  Troponin  Result
# 0           87.0   1.83     0.004       0
# 1          102.0   0.71     0.003       0
# 2          135.0   2.35     0.004       0
# 3          102.0   2.39     0.006       0
# 4          198.0   2.39     0.013       0
# ..           ...    ...       ...     ...
# 434        105.0   1.61     0.009       0
# 438        100.0   4.24     0.003       0
# 441        208.0   1.29     0.009       0
# 442         80.0   4.80     0.009       0
# 448        147.0   5.22     0.011       0
#
# [202 rows x 8 columns]

# %%
# Just seperating some values from orginal dataset for manually testing the model
test_values=core_data.iloc[[446,16,438,3]].copy()
core_data=core_data.drop([446,16,438,3]).copy()

# %% [markdown]
# # Splitting test and train dataset

# %%
X=core_data.drop("Result",axis=1).copy()
Y=core_data["Result"].copy()

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.1,random_state=42)

# %% [markdown]
# # Training the model (model - Random Forest)

# %%
clf=RandomForestClassifier(random_state=42)
clf.fit(X_train,Y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %% [markdown]
# # Model prediction and accuraccy report

# %%
Y_pred=clf.predict(X_test)

# %%
print(classification_report(Y_test,Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        22
#            1       1.00      1.00      1.00        23
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45

# %%
from sklearn.model_selection import cross_val_score
cvs=cross_val_score(clf,X,Y,cv=5,scoring="accuracy")
print(cvs)
# Out:
# [0.96629213 1.         0.98876404 0.98876404 0.98876404]

# %%
mean_accu=np.mean(cvs)
std_accu=np.std(cvs)
print(mean_accu,std_accu)
# Out:
# 0.9865168539325841 0.011008942664194044

# %%
test_values
# Out:
#      Age  Heart rate  Systolic blood pressure  Diastolic blood pressure  \
# 446   60          78                      109                        69
# 16    63          81                      130                        65
# 438   42          70                      117                        76
# 3     44          60                      166                        90
#
#      Blood sugar  CK-MB  Troponin  Result
# 446        230.0  19.47     0.003       1
# 16          98.0   2.28     0.040       1
# 438        100.0   4.24     0.003       0
# 3          102.0   2.39     0.006       0

# %% [markdown]
# # Loading the saved model

# %%
import pickle

# %%
load_model=pickle.load(open('TM_HeartAttack.sav','rb'))

# %% [markdown]
# # Saving the trained model

# %%
filename="TM_HeartAttack.sav"
pickle.dump(clf,open(filename,'wb'))

# %% [markdown]
# # Manual Testing

# %%
s=test_values.iloc[1].to_numpy()
s=s[0:-1].reshape(1,-1)
print(s)
pred=load_model.predict(s)
print(pred)
if(pred[0]==0):
    print("No chances of heart attack")
else:
    print("There is a chance of heart attack")
# Out:
# [[6.30e+01 8.10e+01 1.30e+02 6.50e+01 9.80e+01 2.28e+00 4.00e-02]]
# [1]
# There is a chance of heart attack
# C:\Users\saran\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
